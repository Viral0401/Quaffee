# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Sales.csv")
df.head()
# Out:
#          Date            Timestamp Invoice_No. Payment_Type Order_Type  \
# 0  2024-01-28  2024-01-29 02:25:22       21573         Cash    Dine In
# 1  2024-01-28  2024-01-29 02:17:11       21572         CARD    Dine In
# 2  2024-01-28  2024-01-29 02:17:11       21572         CARD    Dine In
# 3  2024-01-28  2024-01-29 02:11:30       21571         CARD    Dine In
# 4  2024-01-28  2024-01-29 02:11:30       21571         CARD    Dine In
#
#      Area                     Item_Name   Price  Qty.  Sub_Total  ...  \
# 0  Dining                  ORANGE JUICE  285.71   1.0     285.71  ...
# 1  Dining           Iced Latte (350 ML)  214.29   1.0     214.29  ...
# 2  Dining          ALMOND MILK (200 ML)   85.71   1.0      85.71  ...
# 3  Dining               Chicken Calzone   66.67   1.0      66.67  ...
# 4  Dining  Coconut Nankhatai (with Egg)  285.71   1.0     285.71  ...
#
#    Address  GST          Assign_To Non_Taxable SGST_Rate SGST_Amount  \
# 0      NaN  NaN                NaN         0.0       2.5        3.52
# 1      NaN  NaN                NaN         0.0       2.5        5.36
# 2      NaN  NaN                NaN         0.0       2.5        2.14
# 3      NaN  NaN  Allahbaksh Shaikh         0.0       2.5        1.67
# 4      NaN  NaN  Allahbaksh Shaikh         0.0       2.5        7.14
#
#    CGST_Rate CGST_Amount Service_Charge_Rate  Service_Charge_Amount
# 0        2.5        3.52                10.0                  14.07
# 1        2.5        5.36                10.0                  21.43
# 2        2.5        2.14                10.0                   8.57
# 3        2.5        1.67                10.0                   6.67
# 4        2.5        7.14                10.0                  28.57
#
# [5 rows x 32 columns]

# %%
start_index = 6077
df = df[:start_index]

# %%
(df.isnull().sum()*100)/df.shape[0]
# Out:
# Date                       0.032911
# Timestamp                  0.032911
# Invoice_No.                0.032911
# Payment_Type               0.032911
# Order_Type                 0.032911
# Area                      22.050354
# Item_Name                  0.032911
# Price                      0.032911
# Qty.                       0.032911
# Sub_Total                  0.032911
# Discount                   0.032911
# Tax                        0.032911
# Final_Total                0.032911
# Status                     0.032911
# Table_No.                 29.833800
# Server_Name                0.032911
# Covers                     0.032911
# Variation                 19.236465
# Category                   0.032911
# HSN                      100.000000
# Phone                     56.277769
# Name                      48.214580
# Address                   84.202732
# GST                      100.000000
# Assign_To                 67.220668
# Non_Taxable                0.032911
# SGST_Rate                  0.032911
# SGST_Amount                0.032911
# CGST_Rate                  0.032911
# CGST_Amount                0.032911
# Service_Charge_Rate        0.032911
# Service_Charge_Amount      0.032911
# dtype: float64

# %%
# null_sum = df.isnull().sum()

# # Filter out columns where the sum of null values exceeds the threshold (e.g., 90)
# columns_to_drop = null_sum[null_sum >= 90].index

# # Drop the columns
# df.drop(columns=columns_to_drop)

columns_to_drop = ['HSN', 'GST', 'Assign_To', 'Address', 'Phone']
df.drop(columns=columns_to_drop, inplace=True)

# %%
df = df.drop('Variation', axis=1)

# %%
(df.isnull().sum()*100)/df.shape[0]
# Out:
# Date                      0.032911
# Timestamp                 0.032911
# Invoice_No.               0.032911
# Payment_Type              0.032911
# Order_Type                0.032911
# Area                     22.050354
# Item_Name                 0.032911
# Price                     0.032911
# Qty.                      0.032911
# Sub_Total                 0.032911
# Discount                  0.032911
# Tax                       0.032911
# Final_Total               0.032911
# Status                    0.032911
# Table_No.                29.833800
# Server_Name               0.032911
# Covers                    0.032911
# Category                  0.032911
# Name                     48.214580
# Non_Taxable               0.032911
# SGST_Rate                 0.032911
# SGST_Amount               0.032911
# CGST_Rate                 0.032911
# CGST_Amount               0.032911
# Service_Charge_Rate       0.032911
# Service_Charge_Amount     0.032911
# dtype: float64

# %%
columns_to_fill_na = ['Name']
df[columns_to_fill_na] = df[columns_to_fill_na].fillna("NA")

# %%
columns_to_fill_na = ['Table_No.']
df[columns_to_fill_na] = df[columns_to_fill_na].fillna(0)

# %%
df['Area'] = df['Area'].where(
    df['Order_Type'] != 'Pick Up',
    np.where(df['Order_Type'] == 'Dine In', 'Dining', 'Swiggy')
)

# %%
df.head()
# Out:
#          Date            Timestamp Invoice_No. Payment_Type Order_Type  \
# 0  2024-01-28  2024-01-29 02:25:22       21573         Cash    Dine In
# 1  2024-01-28  2024-01-29 02:17:11       21572         CARD    Dine In
# 2  2024-01-28  2024-01-29 02:17:11       21572         CARD    Dine In
# 3  2024-01-28  2024-01-29 02:11:30       21571         CARD    Dine In
# 4  2024-01-28  2024-01-29 02:11:30       21571         CARD    Dine In
#
#      Area                     Item_Name   Price  Qty.  Sub_Total  ...  Covers  \
# 0  Dining                  ORANGE JUICE  285.71   1.0     285.71  ...     0.0
# 1  Dining           Iced Latte (350 ML)  214.29   1.0     214.29  ...     0.0
# 2  Dining          ALMOND MILK (200 ML)   85.71   1.0      85.71  ...     0.0
# 3  Dining               Chicken Calzone   66.67   1.0      66.67  ...     1.0
# 4  Dining  Coconut Nankhatai (with Egg)  285.71   1.0     285.71  ...     1.0
#
#       Category           Name Non_Taxable SGST_Rate SGST_Amount  CGST_Rate  \
# 0       JUICES  sanket rathod         0.0       2.5        3.52        2.5
# 1  Cold Coffee             NA         0.0       2.5        5.36        2.5
# 2         Milk             NA         0.0       2.5        2.14        2.5
# 3    Food Menu           neel         0.0       2.5        1.67        2.5
# 4        Sweet           neel         0.0       2.5        7.14        2.5
#
#   CGST_Amount Service_Charge_Rate  Service_Charge_Amount
# 0        3.52                10.0                  14.07
# 1        5.36                10.0                  21.43
# 2        2.14                10.0                   8.57
# 3        1.67                10.0                   6.67
# 4        7.14                10.0                  28.57
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (6077, 26)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (6075, 26)

# %%
# Specify the columns to keep
columns_to_keep = ['Date', 'Timestamp', 'Item_Name']

# Drop columns not in the specified list
df2 = df[columns_to_keep]

# %%
df2
# Out:
#             Date            Timestamp                     Item_Name
# 0     2024-01-28  2024-01-29 02:25:22                  ORANGE JUICE
# 1     2024-01-28  2024-01-29 02:17:11           Iced Latte (350 ML)
# 2     2024-01-28  2024-01-29 02:17:11          ALMOND MILK (200 ML)
# 3     2024-01-28  2024-01-29 02:11:30               Chicken Calzone
# 4     2024-01-28  2024-01-29 02:11:30  Coconut Nankhatai (with Egg)
# ...          ...                  ...                           ...
# 6070  2024-01-31  2024-01-31 03:21:07        Hot Chocolate (250 Ml)
# 6071  2024-01-31  2024-01-31 03:18:00       Iced Americano (350 Ml)
# 6072  2024-01-31  2024-01-31 03:13:07                Baked Vada Pav
# 6073  2024-01-31  2024-01-31 03:13:07               Baked Pav Bhaji
# 6074  2024-01-31  2024-01-31 03:13:07  Berliners (Nutella Berliner)
#
# [6075 rows x 3 columns]

# %%
# Convert 'Date' and 'Timestamp' to datetime format
df2['Date'] = pd.to_datetime(df2['Date'])
df2['Timestamp'] = pd.to_datetime(df2['Timestamp'])

# Create 'Weekend_Weekday' column
df2['Weekend_Weekday'] = df2['Date'].dt.day_name()  # Get the day name

# Create 'Period' column
df2['Period'] = pd.cut(df2['Timestamp'].dt.hour,
                       bins=[0, 12, 17, 24],
                       labels=['Morning', 'Afternoon', 'Evening'],
                       include_lowest=True)

# %%
df2
# Out:
#            Date           Timestamp                     Item_Name  \
# 0    2024-01-28 2024-01-29 02:25:22                  ORANGE JUICE
# 1    2024-01-28 2024-01-29 02:17:11           Iced Latte (350 ML)
# 2    2024-01-28 2024-01-29 02:17:11          ALMOND MILK (200 ML)
# 3    2024-01-28 2024-01-29 02:11:30               Chicken Calzone
# 4    2024-01-28 2024-01-29 02:11:30  Coconut Nankhatai (with Egg)
# ...         ...                 ...                           ...
# 6070 2024-01-31 2024-01-31 03:21:07        Hot Chocolate (250 Ml)
# 6071 2024-01-31 2024-01-31 03:18:00       Iced Americano (350 Ml)
# 6072 2024-01-31 2024-01-31 03:13:07                Baked Vada Pav
# 6073 2024-01-31 2024-01-31 03:13:07               Baked Pav Bhaji
# 6074 2024-01-31 2024-01-31 03:13:07  Berliners (Nutella Berliner)
#
#      Weekend_Weekday   Period
# 0             Sunday  Morning
# 1             Sunday  Morning
# 2             Sunday  Morning
# 3             Sunday  Morning
# 4             Sunday  Morning
# ...              ...      ...
# 6070       Wednesday  Morning
# 6071       Wednesday  Morning
# 6072       Wednesday  Morning
# 6073       Wednesday  Morning
# 6074       Wednesday  Morning
#
# [6075 rows x 5 columns]

# %%
# Convert 'Timestamp' column to datetime if it's not already in datetime format
df2['Timestamp'] = pd.to_datetime(df2['Timestamp'])

# Sort the dataframe by the 'Timestamp' column
df2 = df2.sort_values(by='Timestamp')

# Assign a unique transaction ID to each group of rows with the same timestamp
df2['Transaction'] = df2.groupby('Timestamp').ngroup() + 1

# %%
df2.head()
# Out:
#            Date           Timestamp  \
# 5577 2024-01-01 2024-01-01 02:44:21
# 5578 2024-01-01 2024-01-01 02:44:21
# 5576 2024-01-01 2024-01-01 02:44:21
# 5575 2024-01-01 2024-01-01 02:44:21
# 5574 2024-01-01 2024-01-01 02:50:49
#
#                                               Item_Name Weekend_Weekday  \
# 5577                                  Papparoti (Plain)          Monday
# 5578                       Gluten Free Hazelnut Brownie          Monday
# 5576  Berliner Mix 3 Pcs (Blueberry Cheese Cake Berl...          Monday
# 5575        Berliner Mix 3 Pcs (Lotus Biscoff Berliner)          Monday
# 5574                          Yellow Banana Chips 60 Gm          Monday
#
#        Period  Transaction
# 5577  Morning            1
# 5578  Morning            1
# 5576  Morning            1
# 5575  Morning            1
# 5574  Morning            2

# %%
from mlxtend.frequent_patterns import association_rules, apriori # for mining frequent itemsets and association rule

import warnings
warnings.filterwarnings("ignore")

# %%
# counting the number of unique transactions
print('The total number of unique transactions is ', df2['Transaction'].nunique())

# counting the number of selling items
print('The total number of unique items is ', df2['Item_Name'].nunique())
# Out:
# The total number of unique transactions is  2889
# The total number of unique items is  192

# %%
df2.head()
# Out:
#            Date           Timestamp  \
# 5577 2024-01-01 2024-01-01 02:44:21
# 5578 2024-01-01 2024-01-01 02:44:21
# 5576 2024-01-01 2024-01-01 02:44:21
# 5575 2024-01-01 2024-01-01 02:44:21
# 5574 2024-01-01 2024-01-01 02:50:49
#
#                                               Item_Name Weekend_Weekday  \
# 5577                                  Papparoti (Plain)          Monday
# 5578                       Gluten Free Hazelnut Brownie          Monday
# 5576  Berliner Mix 3 Pcs (Blueberry Cheese Cake Berl...          Monday
# 5575        Berliner Mix 3 Pcs (Lotus Biscoff Berliner)          Monday
# 5574                          Yellow Banana Chips 60 Gm          Monday
#
#        Period  Transaction
# 5577  Morning            1
# 5578  Morning            1
# 5576  Morning            1
# 5575  Morning            1
# 5574  Morning            2

# %%
df2['Timestamp'] = pd.to_datetime(df2['Timestamp'])

# %%
top_items = pd.DataFrame(df2['Item_Name'].value_counts(dropna=True, sort=True)).reset_index()
top_items.columns = ['item', 'count']
# top_items['percentage'] = top_items['count'].apply(lambda x: x/top_items['count'].sum())
top_items = top_items.head(20)
top_items
# Out:
#                                      item  count
# 0      South Indian Filter Kaapi (150 ML)    338
# 1                          Baked Vada Pav    289
# 2      South Indian Filter Kaapi (250 ML)    243
# 3   Origanal South Indian Frappe (350 ML)    228
# 4                      Cappucino (250 ML)    220
# 5                     Vietnamese (350 ML)    153
# 6                 Classic Frappe (350 ML)    151
# 7                       Papparoti (Plain)    150
# 8                     Iced Latte (350 ML)    148
# 9                  Hot Chocolate (250 ML)    142
# 10               Hazelnut Frappe (350 ML)    138
# 11                     Americano (250 ML)    132
# 12   Madagascar Chocochip Frappe (350 ML)    122
# 13                        Chicken Calzone    112
# 14           Hyderabadi Chicken Keema Pav    112
# 15                Iced Americano (350 ML)    110
# 16       Papparoti (Add On Nutella sauce)    103
# 17                        Baked Pav Bhaji     99
# 18    Choco-crinkle-cookies (COMBO 3 PCS)     98
# 19                     Kaapicino (250 ML)     93

# %%
top_items.to_csv('top_items_data.csv', index=False)

# %% [markdown]
# The above are top 20 items on the menu

# %%
plt.figure(figsize=(30,12))
sns.barplot(x='item', y='count', data=top_items, palette='viridis')
plt.xlabel('Items', size=15)
plt.ylabel('Count of Items', size=15)
plt.title('Top 20 best selling items', size=20)
plt.xticks(rotation=45, ha='right')  # Adjust rotation angle
# plt.xticks(range(0, len(top_items), 2), top_items['item'][::2])  # Display every second label
plt.show()

# %% [markdown]
# this

# %%
df2.head()
# Out:
#            Date           Timestamp  \
# 5577 2024-01-01 2024-01-01 02:44:21
# 5578 2024-01-01 2024-01-01 02:44:21
# 5576 2024-01-01 2024-01-01 02:44:21
# 5575 2024-01-01 2024-01-01 02:44:21
# 5574 2024-01-01 2024-01-01 02:50:49
#
#                                               Item_Name Weekend_Weekday  \
# 5577                                  Papparoti (Plain)          Monday
# 5578                       Gluten Free Hazelnut Brownie          Monday
# 5576  Berliner Mix 3 Pcs (Blueberry Cheese Cake Berl...          Monday
# 5575        Berliner Mix 3 Pcs (Lotus Biscoff Berliner)          Monday
# 5574                          Yellow Banana Chips 60 Gm          Monday
#
#        Period  Transaction
# 5577  Morning            1
# 5578  Morning            1
# 5576  Morning            1
# 5575  Morning            1
# 5574  Morning            2

# %%
df2.head()
# Out:
#            Date           Timestamp  \
# 5577 2024-01-01 2024-01-01 02:44:21
# 5578 2024-01-01 2024-01-01 02:44:21
# 5576 2024-01-01 2024-01-01 02:44:21
# 5575 2024-01-01 2024-01-01 02:44:21
# 5574 2024-01-01 2024-01-01 02:50:49
#
#                                               Item_Name Weekend_Weekday  \
# 5577                                  Papparoti (Plain)          Monday
# 5578                       Gluten Free Hazelnut Brownie          Monday
# 5576  Berliner Mix 3 Pcs (Blueberry Cheese Cake Berl...          Monday
# 5575        Berliner Mix 3 Pcs (Lotus Biscoff Berliner)          Monday
# 5574                          Yellow Banana Chips 60 Gm          Monday
#
#        Period  Transaction
# 5577  Morning            1
# 5578  Morning            1
# 5576  Morning            1
# 5575  Morning            1
# 5574  Morning            2

# %%
# count the number of items of each transaction
items_num = df2.groupby('Transaction', as_index=False)['Item_Name'].count()

# create histogram plot showing the distribution of transactions by the number of items per transaction
ax = sns.histplot(data= items_num, x='Item_Name', discrete=True)
plt.xlabel('Number of Items', size = 12)
ax.set(xticks=items_num['Item_Name'].values)
plt.ylabel('Count of Transactions', size = 12)
plt.title('Number of Items per Transaction', size = 15)
plt.show()

# %%
df2['Timestamp'] = pd.to_datetime(df2['Timestamp'])

# extracting date
df2['date'] = df2['Timestamp'].dt.date

# extracting hour
df2['hour'] = df2['Timestamp'].dt.hour

#extracting weekday
df2['weekday'] = df2['Timestamp'].dt.strftime('%A')

# extracting month and display full name of the month
df2['month'] = df2['Timestamp'].dt.strftime('%Y-%m')

# %%
df2.head()
# Out:
#            Date           Timestamp  \
# 5577 2024-01-01 2024-01-01 02:44:21
# 5578 2024-01-01 2024-01-01 02:44:21
# 5576 2024-01-01 2024-01-01 02:44:21
# 5575 2024-01-01 2024-01-01 02:44:21
# 5574 2024-01-01 2024-01-01 02:50:49
#
#                                               Item_Name Weekend_Weekday  \
# 5577                                  Papparoti (Plain)          Monday
# 5578                       Gluten Free Hazelnut Brownie          Monday
# 5576  Berliner Mix 3 Pcs (Blueberry Cheese Cake Berl...          Monday
# 5575        Berliner Mix 3 Pcs (Lotus Biscoff Berliner)          Monday
# 5574                          Yellow Banana Chips 60 Gm          Monday
#
#        Period  Transaction        date  hour weekday    month
# 5577  Morning            1  2024-01-01     2  Monday  2024-01
# 5578  Morning            1  2024-01-01     2  Monday  2024-01
# 5576  Morning            1  2024-01-01     2  Monday  2024-01
# 5575  Morning            1  2024-01-01     2  Monday  2024-01
# 5574  Morning            2  2024-01-01     2  Monday  2024-01

# %%
df
# Out:
#             Date            Timestamp Invoice_No. Payment_Type  \
# 0     2024-01-28  2024-01-29 02:25:22       21573         Cash
# 1     2024-01-28  2024-01-29 02:17:11       21572         CARD
# 2     2024-01-28  2024-01-29 02:17:11       21572         CARD
# 3     2024-01-28  2024-01-29 02:11:30       21571         CARD
# 4     2024-01-28  2024-01-29 02:11:30       21571         CARD
# ...          ...                  ...         ...          ...
# 6070  2024-01-31  2024-01-31 03:21:07       21725       Online
# 6071  2024-01-31  2024-01-31 03:18:00       21724       Online
# 6072  2024-01-31  2024-01-31 03:13:07       21723         CARD
# 6073  2024-01-31  2024-01-31 03:13:07       21723         CARD
# 6074  2024-01-31  2024-01-31 03:13:07       21723         CARD
#
#             Order_Type    Area                     Item_Name   Price  Qty.  \
# 0              Dine In  Dining                  ORANGE JUICE  285.71   1.0
# 1              Dine In  Dining           Iced Latte (350 ML)  214.29   1.0
# 2              Dine In  Dining          ALMOND MILK (200 ML)   85.71   1.0
# 3              Dine In  Dining               Chicken Calzone   66.67   1.0
# 4              Dine In  Dining  Coconut Nankhatai (with Egg)  285.71   1.0
# ...                ...     ...                           ...     ...   ...
# 6070  Delivery(Parcel)  Zomato        Hot Chocolate (250 Ml)  367.50   1.0
# 6071  Delivery(Parcel)  Zomato       Iced Americano (350 Ml)  252.00   1.0
# 6072           Dine In  Dining                Baked Vada Pav   76.19   1.0
# 6073           Dine In  Dining               Baked Pav Bhaji   76.19   1.0
# 6074           Dine In  Dining  Berliners (Nutella Berliner)   66.67   1.0
#
#       Sub_Total  ...  Covers       Category           Name Non_Taxable  \
# 0        285.71  ...     0.0         JUICES  sanket rathod         0.0
# 1        214.29  ...     0.0    Cold Coffee             NA         0.0
# 2         85.71  ...     0.0           Milk             NA         0.0
# 3         66.67  ...     1.0      Food Menu           neel         0.0
# 4        285.71  ...     1.0          Sweet           neel         0.0
# ...         ...  ...     ...            ...            ...         ...
# 6070     367.50  ...     0.0  Hot Chocolate       Veronica       247.5
# 6071     252.00  ...     0.0    Cold Coffee     Dania Noor       132.0
# 6072      76.19  ...     0.0      Food Menu             NA         0.0
# 6073      76.19  ...     0.0      Food Menu             NA         0.0
# 6074      66.67  ...     0.0      Food Menu             NA         0.0
#
#      SGST_Rate SGST_Amount  CGST_Rate CGST_Amount Service_Charge_Rate  \
# 0          2.5        3.52        2.5        3.52                10.0
# 1          2.5        5.36        2.5        5.36                10.0
# 2          2.5        2.14        2.5        2.14                10.0
# 3          2.5        1.67        2.5        1.67                10.0
# 4          2.5        7.14        2.5        7.14                10.0
# ...        ...         ...        ...         ...                 ...
# 6070       2.5        0.00        2.5        0.00                10.0
# 6071       2.5        0.00        2.5        0.00                10.0
# 6072       2.5        1.90        2.5        1.90                10.0
# 6073       2.5        1.90        2.5        1.90                10.0
# 6074       2.5        1.67        2.5        1.67                10.0
#
#       Service_Charge_Amount
# 0                     14.07
# 1                     21.43
# 2                      8.57
# 3                      6.67
# 4                     28.57
# ...                     ...
# 6070                   0.00
# 6071                   0.00
# 6072                   7.62
# 6073                   7.62
# 6074                   6.67
#
# [6075 rows x 26 columns]

# %%
df2 = df2.drop('date', axis=1, errors='ignore')
df2.head()
# Out:
#            Date           Timestamp  \
# 5577 2024-01-01 2024-01-01 02:44:21
# 5578 2024-01-01 2024-01-01 02:44:21
# 5576 2024-01-01 2024-01-01 02:44:21
# 5575 2024-01-01 2024-01-01 02:44:21
# 5574 2024-01-01 2024-01-01 02:50:49
#
#                                               Item_Name Weekend_Weekday  \
# 5577                                  Papparoti (Plain)          Monday
# 5578                       Gluten Free Hazelnut Brownie          Monday
# 5576  Berliner Mix 3 Pcs (Blueberry Cheese Cake Berl...          Monday
# 5575        Berliner Mix 3 Pcs (Lotus Biscoff Berliner)          Monday
# 5574                          Yellow Banana Chips 60 Gm          Monday
#
#        Period  Transaction  hour weekday    month
# 5577  Morning            1     2  Monday  2024-01
# 5578  Morning            1     2  Monday  2024-01
# 5576  Morning            1     2  Monday  2024-01
# 5575  Morning            1     2  Monday  2024-01
# 5574  Morning            2     2  Monday  2024-01

# %%
df2['Date'] = pd.to_datetime(df2['Date'])

# Calculate the week number using isocalendar()
df2['Week_Number'] = df2['Date'].dt.isocalendar().week

# Display the updated DataFrame
print(df2[['Date', 'Week_Number']])
# Out:
#            Date  Week_Number
# 5577 2024-01-01            1
# 5578 2024-01-01            1
# 5576 2024-01-01            1
# 5575 2024-01-01            1
# 5574 2024-01-01            1
# ...         ...          ...
# 5910 2024-01-31            5
# 5909 2024-01-31            5
# 5911 2024-01-31            5
# 5907 2024-01-31            5
# 5908 2024-01-31            5
#
# [6075 rows x 2 columns]

# %%
df2
# Out:
#            Date           Timestamp  \
# 5577 2024-01-01 2024-01-01 02:44:21
# 5578 2024-01-01 2024-01-01 02:44:21
# 5576 2024-01-01 2024-01-01 02:44:21
# 5575 2024-01-01 2024-01-01 02:44:21
# 5574 2024-01-01 2024-01-01 02:50:49
# ...         ...                 ...
# 5910 2024-01-31 2024-02-01 02:22:33
# 5909 2024-01-31 2024-02-01 02:22:33
# 5911 2024-01-31 2024-02-01 02:22:33
# 5907 2024-01-31 2024-02-01 02:27:47
# 5908 2024-01-31 2024-02-01 02:27:47
#
#                                               Item_Name Weekend_Weekday  \
# 5577                                  Papparoti (Plain)          Monday
# 5578                       Gluten Free Hazelnut Brownie          Monday
# 5576  Berliner Mix 3 Pcs (Blueberry Cheese Cake Berl...          Monday
# 5575        Berliner Mix 3 Pcs (Lotus Biscoff Berliner)          Monday
# 5574                          Yellow Banana Chips 60 Gm          Monday
# ...                                                 ...             ...
# 5910                                    Chicken Calzone       Wednesday
# 5909         Berliners (Blueberry Cheese Cake Berliner)       Wednesday
# 5911                         Calzones Veg (Calzone Veg)       Wednesday
# 5907                      Calzones Veg (Calzone Paneer)       Wednesday
# 5908                                 Cappucino (250 ML)       Wednesday
#
#        Period  Transaction  hour   weekday    month  Week_Number
# 5577  Morning            1     2    Monday  2024-01            1
# 5578  Morning            1     2    Monday  2024-01            1
# 5576  Morning            1     2    Monday  2024-01            1
# 5575  Morning            1     2    Monday  2024-01            1
# 5574  Morning            2     2    Monday  2024-01            1
# ...       ...          ...   ...       ...      ...          ...
# 5910  Morning         2888     2  Thursday  2024-02            5
# 5909  Morning         2888     2  Thursday  2024-02            5
# 5911  Morning         2888     2  Thursday  2024-02            5
# 5907  Morning         2889     2  Thursday  2024-02            5
# 5908  Morning         2889     2  Thursday  2024-02            5
#
# [6075 rows x 10 columns]

# %%
# Convert 'Date' column to datetime format
df2['Date'] = pd.to_datetime(df2['Date'])

# Calculate the week number using isocalendar()
df2['Week_Number'] = df2['Date'].dt.isocalendar().week

# Display the unique values in the 'Week_Number' column
unique_week_numbers = df2['Week_Number'].unique()
print("Unique Week Numbers:", unique_week_numbers)
# Out:
# Unique Week Numbers: <IntegerArray>
# [1, 2, 3, 4, 5]
# Length: 5, dtype: UInt32

# %%
# count the quantity of items sold by month and year
qty_month = df2.groupby('month', as_index=False)['Transaction'].count()
qty_month.head()

# create bar plot showing the number of items sold by month
plt.figure(figsize=(12,5))
sns.barplot(x = 'month', y = 'Transaction', data = qty_month, palette = 'viridis')
plt.xlabel('Month', size = 12)
plt.xticks(rotation=45)
plt.ylabel('Count of Items', size = 12)
plt.title('Quantity Sold by Month', size = 15)
plt.grid(axis = 'y', ls='--', lw='0.5')
plt.show()

# %%
# count the number of transactions by days of week, reorder by names of the days
qty_wd = df2.groupby('weekday', as_index=False)['Transaction'].count()
qty_wd['weekday'] = pd.Categorical(qty_wd['weekday'], categories=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday' ,'Saturday', 'Sunday'], ordered=True)
qty_wd.sort_values("weekday", inplace=True)
qty_wd
# Out:
#      weekday  Transaction
# 1     Monday          789
# 5    Tuesday          806
# 6  Wednesday          876
# 4   Thursday          741
# 0     Friday          793
# 2   Saturday          990
# 3     Sunday         1080

# %%
plt.figure(figsize=(8,5))
sns.barplot(x = 'weekday', y = 'Transaction', data = qty_wd, palette = 'viridis')
plt.xlabel('Day of Week', size = 12)
plt.ylabel('Count of Items', size = 12)
plt.title('Quantity Sold by Days of Week', size = 15)
plt.grid(axis = 'y', ls='--', lw='0.5')
plt.show()

# %%
df2.head()
# Out:
#            Date           Timestamp  \
# 5577 2024-01-01 2024-01-01 02:44:21
# 5578 2024-01-01 2024-01-01 02:44:21
# 5576 2024-01-01 2024-01-01 02:44:21
# 5575 2024-01-01 2024-01-01 02:44:21
# 5574 2024-01-01 2024-01-01 02:50:49
#
#                                               Item_Name Weekend_Weekday  \
# 5577                                  Papparoti (Plain)          Monday
# 5578                       Gluten Free Hazelnut Brownie          Monday
# 5576  Berliner Mix 3 Pcs (Blueberry Cheese Cake Berl...          Monday
# 5575        Berliner Mix 3 Pcs (Lotus Biscoff Berliner)          Monday
# 5574                          Yellow Banana Chips 60 Gm          Monday
#
#        Period  Transaction  hour weekday    month
# 5577  Morning            1     2  Monday  2024-01
# 5578  Morning            1     2  Monday  2024-01
# 5576  Morning            1     2  Monday  2024-01
# 5575  Morning            1     2  Monday  2024-01
# 5574  Morning            2     2  Monday  2024-01

# %%
plt.figure(figsize=(8,5))
sns.barplot(x = 'weekday', y = 'Transaction', data = qty_wd, palette = 'viridis')
plt.xlabel('Day of Week', size = 12)
plt.ylabel('Count of Items', size = 12)
plt.title('Quantity Sold by Days of Week', size = 15)
plt.grid(axis = 'y', ls='--', lw='0.5')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming qty_wd is your DataFrame
# If not, replace it with your actual DataFrame

# Group by weekday and sum the transactions
daily_transaction_sum = qty_wd.groupby('weekday')['Transaction'].sum()

# Print the values
daily_transaction_sum
# Out:
# weekday
# Monday        789
# Tuesday       806
# Wednesday     876
# Thursday      741
# Friday        793
# Saturday      990
# Sunday       1080
# Name: Transaction, dtype: int64

# %%
qty_hr = df2.groupby('hour', as_index=False)['Transaction'].count()
qty_hr['hour_bins'] = pd.cut(x=qty_hr.hour, bins = range(0,24,1))
qty_hr.head()

# visualize the distribution of items sold quantity by hours
plt.figure(figsize=(8,5))
sns.barplot(x = 'Transaction', y = 'hour_bins', data = qty_hr, palette = 'viridis')
plt.xlabel('Count of Items', size = 12)
plt.ylabel('Hours', size = 12)
plt.title('Quantity Sold by Hours', size = 15)
plt.show()

# %%
# Apply Apriori Algorithm to implement Market Basket Analysis

# select only required variables for modelling
transactions = df2.groupby(['Transaction', 'Item_Name'])['Item_Name'].count().reset_index(name ='Count')
transactions.head()

# The `apriori` function expects input data in a one-hot encoded pandas DataFrame, therefore,
# we need to transform the dataframe above into the representation of categorical variables as binary vectors.

# first create a mxn matrice where m=transaction and n=items
# each row represents whether the items was in a specific transaction or not (>=1 returns True (1), 0 returns 0)
my_basket = transactions.pivot_table(index='Transaction', columns='Item_Name', values='Count', aggfunc='any').fillna(0)

my_basket.head()

# create frequent items df with itemsets and support columns by using `apriori` function
frequent_items = apriori(my_basket, min_support = 0.01, use_colnames = True)
frequent_items

# create the rules from frequent itemset generated above with min lift = 1.2
rules = association_rules(frequent_items, metric = "lift", min_threshold = 1.2)
rules.sort_values('confidence', ascending = False, inplace = True)
rules.reset_index(drop=True, inplace = True)
rules.head()
# Out:
#                                          antecedents  \
# 0  (Rosella Jam With Filter Coffee Ganache Macaro...
# 1  (Strawberry White Chocolate Ganache With Rosel...
# 2                                  (Baked Pav Bhaji)
# 3                    (Calzones Veg (Calzone Paneer))
# 4                                   (Baked Vada Pav)
#
#                                          consequents  antecedent support  \
# 0  (Strawberry White Chocolate Ganache With Rosel...            0.019384
# 1  (Rosella Jam With Filter Coffee Ganache Macaro...            0.026999
# 2                                   (Baked Vada Pav)            0.033576
# 3                                   (Baked Vada Pav)            0.029076
# 4                                  (Baked Pav Bhaji)            0.096919
#
#    consequent support   support  confidence       lift  leverage  conviction  \
# 0            0.026999  0.011076    0.571429  21.164835  0.010553    2.270336
# 1            0.019384  0.011076    0.410256  21.164835  0.010553    1.662784
# 2            0.096919  0.013499    0.402062   4.148417  0.010245    1.510325
# 3            0.096919  0.010730    0.369048   3.807781  0.007912    1.431298
# 4            0.033576  0.013499    0.139286   4.148417  0.010245    1.122817
#
#    zhangs_metric
# 0       0.971585
# 1       0.979189
# 2       0.785312
# 3       0.759462
# 4       0.840395

# %%
def rules_to_coordinates(rules):
    rules['antecedent'] = rules['antecedents'].apply(lambda antecedent: list(antecedent)[0])
    rules['consequent'] = rules['consequents'].apply(lambda consequent: list(consequent)[0])
    rules['rule'] = rules.index
    return rules[['antecedent','consequent','rule']]

# import sub lib to plot parallel coordinates
from pandas.plotting import parallel_coordinates

# Convert rules into coordinates suitable for use in a parallel coordinates plot
coords = rules_to_coordinates(rules)

# Generate parallel coordinates plot
plt.figure(figsize=(10,20))
parallel_coordinates(coords, 'rule')
plt.legend([])
plt.grid(ls='--', lw='0.5')
plt.title('Parallel coordinates', size = 15)
plt.show()

# %%
rules_copy = rules.copy()
columns_to_keep = ['antecedent','consequent','rule']

# Drop columns
columns_to_drop = set(rules_copy.columns) - set(columns_to_keep)
rules_copy.drop(columns=columns_to_drop, inplace=True)

rules_copy.head()
# Out:
#                                           antecedent  \
# 0  Rosella Jam With Filter Coffee Ganache Macaroo...
# 1  Strawberry White Chocolate Ganache With Rosell...
# 2                                    Baked Pav Bhaji
# 3                      Calzones Veg (Calzone Paneer)
# 4                                     Baked Vada Pav
#
#                                           consequent  rule
# 0  Strawberry White Chocolate Ganache With Rosell...     0
# 1  Rosella Jam With Filter Coffee Ganache Macaroo...     1
# 2                                     Baked Vada Pav     2
# 3                                     Baked Vada Pav     3
# 4                                    Baked Pav Bhaji     4

# %%
# rules_copy.to_csv('parallel.csv', index=False)
# # from google.colab import files
# files.download('parallel.csv')

# %%
# Itemsets Lift Heatmap

# convert antecedents and consequents into strings
rules['antecedents'] = rules['antecedents'].apply(lambda a: ','.join(list(a)))
rules['consequents'] = rules['consequents'].apply(lambda a: ','.join(list(a)))

# transform antecedent, consequent, and support columns into matrix
support_table_lift = rules.pivot(index='consequents', columns='antecedents', values='lift')

# generate a heatmap with annotations
plt.figure(figsize=(10,6))
sns.heatmap(support_table_lift, annot = True, cbar = True, cmap="RdPu")
plt.suptitle('Itemsets Lift', size = 15)
plt.title('How many times the antecedents and the consequents occur together more often than random?\n', size=10)
plt.show()

# %%
# Itemsets Confidence Heatmap

# transform antecedent, consequent, and support columns into matrix
rules_confidence = rules[rules['confidence']>=0.2] # select min lift=1.2
support_table_conf = rules_confidence.pivot(index='consequents', columns='antecedents', values='confidence')

# generate a heatmap with annotations
plt.figure(figsize=(10,6))
sns.heatmap(support_table_conf, annot = True, cbar = True, cmap="BuPu")
plt.suptitle('Itemsets Confidence', size = 15)
plt.title('How often the consequents is purchased given that the antecedents was purchased?\n', size = 10)
plt.show()
